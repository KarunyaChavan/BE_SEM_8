# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# # Loading Dataset

# %%
cols = ["letter","x-box","y-box","width","height","onpix","x-bar","y-bar",
        "x2bar","y2bar","xybar","x2ybr","xy2br","x-ege","xegvy","y-ege","yegvx"]

df = pd.read_csv("datasets/letter-recognition.data", names=cols)

# %% [markdown]
# # Exploring Dataset

# %% [markdown]
# ## Size and Dimensions

# %%
print(f"No. of Rows : {df.shape[0]}\nNo. of Columns : {df.shape[1]}\nTotal No. of Cells : {df.size}")
# Out:
# No. of Rows : 20000
# No. of Columns : 17
# Total No. of Cells : 340000

# %% [markdown]
# ## Displaying Sample Rows

# %%
print("Top 5 rows")
display(df.head())
# Out:
# Top 5 rows
#   letter  x-box  y-box  width  height  onpix  x-bar  y-bar  x2bar  y2bar  \
# 0      T      2      8      3       5      1      8     13      0      6
# 1      I      5     12      3       7      2     10      5      5      4
# 2      D      4     11      6       8      6     10      6      2      6
# 3      N      7     11      6       6      3      5      9      4      6
# 4      G      2      1      3       1      1      8      6      6      6
#
#    xybar  x2ybr  xy2br  x-ege  xegvy  y-ege  yegvx
# 0      6     10      8      0      8      0      8
# 1     13      3      9      2      8      4     10
# 2     10      3      7      3      7      3      9
# 3      4      4     10      6     10      2      8
# 4      6      5      9      1      7      5     10

# %%
print("Last 5 rows")
display(df.tail())
# Out:
# Last 5 rows
#       letter  x-box  y-box  width  height  onpix  x-bar  y-bar  x2bar  y2bar  \
# 19995      D      2      2      3       3      2      7      7      7      6
# 19996      C      7     10      8       8      4      4      8      6      9
# 19997      T      6      9      6       7      5      6     11      3      7
# 19998      S      2      3      4       2      1      8      7      2      6
# 19999      A      4      9      6       6      2      9      5      3      1
#
#        xybar  x2ybr  xy2br  x-ege  xegvy  y-ege  yegvx
# 19995      6      6      4      2      8      3      7
# 19996     12      9     13      2      9      3      7
# 19997     11      9      5      2     12      2      4
# 19998     10      6      8      1      9      5      8
# 19999      8      1      8      2      7      2      8

# %%
print("Randomly selected 5 rows")
display(df.sample(5))
# Out:
# Randomly selected 5 rows
#       letter  x-box  y-box  width  height  onpix  x-bar  y-bar  x2bar  y2bar  \
# 4607       N      5     10      6       8      3      7      7     15      2
# 3383       R      2      1      2       2      2      6      7      5      5
# 15018      C      5      7      6       5      6      5      6      4      4
# 8893       U      4      4      5       3      2      4      9      5      7
# 2851       I      1     11      0       8      0      7      7      4      4
#
#        xybar  x2ybr  xy2br  x-ege  xegvy  y-ege  yegvx
# 4607       4      6      8      6      8      0      8
# 3383       6      5      6      2      7      4      8
# 15018      7      7      9      5     10      4      8
# 8893      11     10      9      3      9      2      7
# 2851       7      6      8      0      8      0      8

# %% [markdown]
# # MetaData

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   letter  20000 non-null  object
#  1   x-box   20000 non-null  int64
#  2   y-box   20000 non-null  int64
#  3   width   20000 non-null  int64
#  4   height  20000 non-null  int64
#  5   onpix   20000 non-null  int64
#  6   x-bar   20000 non-null  int64
#  7   y-bar   20000 non-null  int64
#  8   x2bar   20000 non-null  int64
#  9   y2bar   20000 non-null  int64
#  10  xybar   20000 non-null  int64
#  11  x2ybr   20000 non-null  int64
#  12  xy2br   20000 non-null  int64
#  13  x-ege   20000 non-null  int64
#  14  xegvy   20000 non-null  int64
#  15  y-ege   20000 non-null  int64
#  16  yegvx   20000 non-null  int64
# dtypes: int64(16), object(1)
# memory usage: 2.6+ MB
# None

# %% [markdown]
# # Statistical Summary

# %%
display(df.describe())
# Out:
#               x-box         y-box         width       height         onpix  \
# count  20000.000000  20000.000000  20000.000000  20000.00000  20000.000000
# mean       4.023550      7.035500      5.121850      5.37245      3.505850
# std        1.913212      3.304555      2.014573      2.26139      2.190458
# min        0.000000      0.000000      0.000000      0.00000      0.000000
# 25%        3.000000      5.000000      4.000000      4.00000      2.000000
# 50%        4.000000      7.000000      5.000000      6.00000      3.000000
# 75%        5.000000      9.000000      6.000000      7.00000      5.000000
# max       15.000000     15.000000     15.000000     15.00000     15.000000
#
#               x-bar         y-bar         x2bar         y2bar         xybar  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       6.897600      7.500450      4.628600      5.178650      8.282050
# std        2.026035      2.325354      2.699968      2.380823      2.488475
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        6.000000      6.000000      3.000000      4.000000      7.000000
# 50%        7.000000      7.000000      4.000000      5.000000      8.000000
# 75%        8.000000      9.000000      6.000000      7.000000     10.000000
# max       15.000000     15.000000     15.000000     15.000000     15.000000
#
#              x2ybr         xy2br         x-ege         xegvy         y-ege  \
# count  20000.00000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       6.45400      7.929000      3.046100      8.338850      3.691750
# std        2.63107      2.080619      2.332541      1.546722      2.567073
# min        0.00000      0.000000      0.000000      0.000000      0.000000
# 25%        5.00000      7.000000      1.000000      8.000000      2.000000
# 50%        6.00000      8.000000      3.000000      8.000000      3.000000
# 75%        8.00000      9.000000      4.000000      9.000000      5.000000
# max       15.00000     15.000000     15.000000     15.000000     15.000000
#
#              yegvx
# count  20000.00000
# mean       7.80120
# std        1.61747
# min        0.00000
# 25%        7.00000
# 50%        8.00000
# 75%        9.00000
# max       15.00000

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='letter', data=df)
plt.title("Class Distribution")
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.drop('letter', axis=1).corr(), cmap='coolwarm')
plt.title("Feature Correlation")
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
X = df.drop('letter', axis=1)
y = df['letter']

# Encode labels
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Train test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42
)

# Scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# One hot encoding
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# # Model Architecture

# %%
model = Sequential()

model.add(Dense(512, activation='relu', input_shape=(16,)))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())

model.add(Dense(26, activation='softmax'))

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# C:\Users\Karunya\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                      │ (None, 512)                 │           8,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 26)                  │           3,354 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 179,866 (702.60 KB)
#  Trainable params: 178,074 (695.60 KB)
#  Non-trainable params: 1,792 (7.00 KB)

# %% [markdown]
# # Training

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

history = model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.4682 - loss: 1.9032 - val_accuracy: 0.8116 - val_loss: 0.7196
# Epoch 2/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7595 - loss: 0.7927 - val_accuracy: 0.8872 - val_loss: 0.3974
# Epoch 3/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8115 - loss: 0.6139 - val_accuracy: 0.9025 - val_loss: 0.3266
# Epoch 4/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8304 - loss: 0.5293 - val_accuracy: 0.9234 - val_loss: 0.2671
# Epoch 5/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8452 - loss: 0.4748 - val_accuracy: 0.9322 - val_loss: 0.2332
# Epoch 6/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8746 - loss: 0.4024 - val_accuracy: 0.9328 - val_loss: 0.2203
# Epoch 7/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8706 - loss: 0.3919 - val_accuracy: 0.9453 - val_loss: 0.1904
# Epoch 8/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8842 - loss: 0.3504 - val_accuracy: 0.9469 - val_loss: 0.1756
# Epoch 9/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8948 - loss: 0.3357 - val_accuracy: 0.9531 - val_loss: 0.1686
# Epoch 10/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8870 - loss: 0.3474 - val_accuracy: 0.9484 - val_loss: 0.1729
# Epoch 11/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8997 - loss: 0.2905 - val_accuracy: 0.9503 - val_loss: 0.1589
# Epoch 12/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9061 - loss: 0.2871 - val_accuracy: 0.9566 - val_loss: 0.1464
# Epoch 13/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9015 - loss: 0.2900 - val_accuracy: 0.9556 - val_loss: 0.1453
# Epoch 14/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9101 - loss: 0.2657 - val_accuracy: 0.9572 - val_loss: 0.1360
# Epoch 15/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9184 - loss: 0.2391 - val_accuracy: 0.9575 - val_loss: 0.1345
# Epoch 16/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9171 - loss: 0.2480 - val_accuracy: 0.9613 - val_loss: 0.1280
# Epoch 17/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9169 - loss: 0.2434 - val_accuracy: 0.9559 - val_loss: 0.1347
# Epoch 18/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9216 - loss: 0.2339 - val_accuracy: 0.9594 - val_loss: 0.1302
# Epoch 19/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9266 - loss: 0.2235 - val_accuracy: 0.9622 - val_loss: 0.1154
# Epoch 20/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9275 - loss: 0.2157 - val_accuracy: 0.9591 - val_loss: 0.1164
# Epoch 21/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9281 - loss: 0.2099 - val_accuracy: 0.9625 - val_loss: 0.1131
# Epoch 22/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9225 - loss: 0.2285 - val_accuracy: 0.9603 - val_loss: 0.1151
# Epoch 23/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9356 - loss: 0.1956 - val_accuracy: 0.9594 - val_loss: 0.1166
# Epoch 24/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9301 - loss: 0.2083 - val_accuracy: 0.9603 - val_loss: 0.1204
# Epoch 25/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9318 - loss: 0.1978 - val_accuracy: 0.9663 - val_loss: 0.0984
# Epoch 26/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9355 - loss: 0.1935 - val_accuracy: 0.9625 - val_loss: 0.1162
# Epoch 27/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9314 - loss: 0.2023 - val_accuracy: 0.9634 - val_loss: 0.0958
# Epoch 28/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9365 - loss: 0.1897 - val_accuracy: 0.9672 - val_loss: 0.0994
# Epoch 29/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9347 - loss: 0.1885 - val_accuracy: 0.9681 - val_loss: 0.0991
# Epoch 30/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9373 - loss: 0.1821 - val_accuracy: 0.9700 - val_loss: 0.0903
# Epoch 31/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9384 - loss: 0.1783 - val_accuracy: 0.9666 - val_loss: 0.1003
# Epoch 32/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9330 - loss: 0.1885 - val_accuracy: 0.9644 - val_loss: 0.1013
# Epoch 33/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9355 - loss: 0.1827 - val_accuracy: 0.9659 - val_loss: 0.0989
# Epoch 34/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9381 - loss: 0.1753 - val_accuracy: 0.9712 - val_loss: 0.0866
# Epoch 35/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9415 - loss: 0.1756 - val_accuracy: 0.9700 - val_loss: 0.0910
# Epoch 36/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9410 - loss: 0.1697 - val_accuracy: 0.9684 - val_loss: 0.0883
# Epoch 37/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9393 - loss: 0.1833 - val_accuracy: 0.9703 - val_loss: 0.0879
# Epoch 38/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9436 - loss: 0.1629 - val_accuracy: 0.9712 - val_loss: 0.0849
# Epoch 39/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9467 - loss: 0.1543 - val_accuracy: 0.9719 - val_loss: 0.0865
# Epoch 40/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9471 - loss: 0.1491 - val_accuracy: 0.9697 - val_loss: 0.0852
# Epoch 41/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9505 - loss: 0.1389 - val_accuracy: 0.9669 - val_loss: 0.0926
# Epoch 42/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9463 - loss: 0.1544 - val_accuracy: 0.9722 - val_loss: 0.0814
# Epoch 43/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9490 - loss: 0.1577 - val_accuracy: 0.9691 - val_loss: 0.0906
# Epoch 44/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9546 - loss: 0.1391 - val_accuracy: 0.9712 - val_loss: 0.0854
# Epoch 45/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9475 - loss: 0.1575 - val_accuracy: 0.9678 - val_loss: 0.0854
# Epoch 46/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9502 - loss: 0.1445 - val_accuracy: 0.9694 - val_loss: 0.0887
# Epoch 47/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9500 - loss: 0.1477 - val_accuracy: 0.9684 - val_loss: 0.0905
# Epoch 48/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9533 - loss: 0.1406 - val_accuracy: 0.9716 - val_loss: 0.0841
# Epoch 49/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9511 - loss: 0.1586 - val_accuracy: 0.9706 - val_loss: 0.0801
# Epoch 50/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9494 - loss: 0.1410 - val_accuracy: 0.9722 - val_loss: 0.0804
# Epoch 51/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9549 - loss: 0.1390 - val_accuracy: 0.9716 - val_loss: 0.0777
# Epoch 52/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9520 - loss: 0.1389 - val_accuracy: 0.9706 - val_loss: 0.0841
# Epoch 53/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9495 - loss: 0.1420 - val_accuracy: 0.9700 - val_loss: 0.0831
# Epoch 54/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9522 - loss: 0.1397 - val_accuracy: 0.9700 - val_loss: 0.0770
# Epoch 55/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9493 - loss: 0.1445 - val_accuracy: 0.9762 - val_loss: 0.0775
# Epoch 56/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9542 - loss: 0.1372 - val_accuracy: 0.9706 - val_loss: 0.0829
# Epoch 57/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9541 - loss: 0.1395 - val_accuracy: 0.9734 - val_loss: 0.0759
# Epoch 58/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9542 - loss: 0.1281 - val_accuracy: 0.9716 - val_loss: 0.0877
# Epoch 59/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9550 - loss: 0.1364 - val_accuracy: 0.9719 - val_loss: 0.0835
# Epoch 60/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9530 - loss: 0.1347 - val_accuracy: 0.9744 - val_loss: 0.0784
# Epoch 61/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9555 - loss: 0.1277 - val_accuracy: 0.9716 - val_loss: 0.0830
# Epoch 62/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9592 - loss: 0.1270 - val_accuracy: 0.9700 - val_loss: 0.0849
# Epoch 63/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9573 - loss: 0.1257 - val_accuracy: 0.9756 - val_loss: 0.0717
# Epoch 64/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9587 - loss: 0.1254 - val_accuracy: 0.9734 - val_loss: 0.0770
# Epoch 65/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9612 - loss: 0.1159 - val_accuracy: 0.9744 - val_loss: 0.0733
# Epoch 66/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9586 - loss: 0.1171 - val_accuracy: 0.9747 - val_loss: 0.0741
# Epoch 67/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9557 - loss: 0.1209 - val_accuracy: 0.9722 - val_loss: 0.0822
# Epoch 68/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9582 - loss: 0.1187 - val_accuracy: 0.9759 - val_loss: 0.0731
# Epoch 69/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9624 - loss: 0.1092 - val_accuracy: 0.9712 - val_loss: 0.0828
# Epoch 70/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9579 - loss: 0.1238 - val_accuracy: 0.9725 - val_loss: 0.0843
# Epoch 71/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9560 - loss: 0.1249 - val_accuracy: 0.9734 - val_loss: 0.0752
# Epoch 72/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9531 - loss: 0.1432 - val_accuracy: 0.9747 - val_loss: 0.0689
# Epoch 73/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9584 - loss: 0.1134 - val_accuracy: 0.9719 - val_loss: 0.0769
# Epoch 74/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9589 - loss: 0.1240 - val_accuracy: 0.9734 - val_loss: 0.0729
# Epoch 75/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9640 - loss: 0.1041 - val_accuracy: 0.9753 - val_loss: 0.0740
# Epoch 76/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9597 - loss: 0.1096 - val_accuracy: 0.9741 - val_loss: 0.0720
# Epoch 77/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9617 - loss: 0.1125 - val_accuracy: 0.9747 - val_loss: 0.0758
# Epoch 78/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9580 - loss: 0.1171 - val_accuracy: 0.9744 - val_loss: 0.0727
# Epoch 79/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9636 - loss: 0.1068 - val_accuracy: 0.9762 - val_loss: 0.0702
# Epoch 80/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9609 - loss: 0.1168 - val_accuracy: 0.9775 - val_loss: 0.0736
# Epoch 81/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9654 - loss: 0.1032 - val_accuracy: 0.9719 - val_loss: 0.0826
# Epoch 82/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9596 - loss: 0.1207 - val_accuracy: 0.9762 - val_loss: 0.0680
# Epoch 83/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9666 - loss: 0.0958 - val_accuracy: 0.9775 - val_loss: 0.0702
# Epoch 84/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9636 - loss: 0.1093 - val_accuracy: 0.9756 - val_loss: 0.0740
# Epoch 85/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9602 - loss: 0.1197 - val_accuracy: 0.9769 - val_loss: 0.0721
# Epoch 86/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9608 - loss: 0.1200 - val_accuracy: 0.9734 - val_loss: 0.0740
# Epoch 87/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9654 - loss: 0.1047 - val_accuracy: 0.9766 - val_loss: 0.0705
# Epoch 88/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9632 - loss: 0.1065 - val_accuracy: 0.9794 - val_loss: 0.0681
# Epoch 89/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9625 - loss: 0.1060 - val_accuracy: 0.9769 - val_loss: 0.0703
# Epoch 90/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9658 - loss: 0.1012 - val_accuracy: 0.9769 - val_loss: 0.0696
# Epoch 91/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9624 - loss: 0.1105 - val_accuracy: 0.9787 - val_loss: 0.0696
# Epoch 92/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9628 - loss: 0.1091 - val_accuracy: 0.9784 - val_loss: 0.0667
# Epoch 93/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9637 - loss: 0.1064 - val_accuracy: 0.9784 - val_loss: 0.0647
# Epoch 94/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9653 - loss: 0.0978 - val_accuracy: 0.9762 - val_loss: 0.0715
# Epoch 95/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9663 - loss: 0.0940 - val_accuracy: 0.9759 - val_loss: 0.0724
# Epoch 96/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9595 - loss: 0.1147 - val_accuracy: 0.9762 - val_loss: 0.0680
# Epoch 97/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9667 - loss: 0.0940 - val_accuracy: 0.9787 - val_loss: 0.0692
# Epoch 98/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9614 - loss: 0.1115 - val_accuracy: 0.9753 - val_loss: 0.0733
# Epoch 99/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9638 - loss: 0.1011 - val_accuracy: 0.9766 - val_loss: 0.0686
# Epoch 100/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9642 - loss: 0.0990 - val_accuracy: 0.9747 - val_loss: 0.0723

# %% [markdown]
# ## Training v/s Validation Loss

# %%
plt.figure(figsize=(8,5))

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.title('Training vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# # Evaluation

# %%
loss, acc = model.evaluate(X_test, y_test)
print("Test Accuracy:", acc)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9819 - loss: 0.0629
# Test Accuracy: 0.9819999933242798

# %% [markdown]
# # Predictions

# %%
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

print("Accuracy:", accuracy_score(y_true, y_pred_classes))
print(classification_report(y_true, y_pred_classes))
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Accuracy: 0.982
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       149
#            1       0.96      0.97      0.96       153
#            2       0.99      0.99      0.99       137
#            3       0.97      0.99      0.98       156
#            4       0.98      0.99      0.98       141
#            5       0.98      0.99      0.98       140
#            6       0.99      0.97      0.98       160
#            7       0.97      0.93      0.95       144
#            8       0.97      0.97      0.97       146
#            9       0.97      0.97      0.97       149
#           10       0.98      0.97      0.98       130
#           11       0.99      0.99      0.99       155
#           12       0.99      1.00      1.00       168
#           13       1.00      0.97      0.99       151
#           14       0.99      0.97      0.98       145
#           15       0.98      0.98      0.98       173
#           16       0.98      0.99      0.98       166
#           17       0.95      0.99      0.97       160
#           18       1.00      0.99      1.00       171
#           19       0.98      0.98      0.98       163
#           20       0.99      0.99      0.99       183
#           21       0.96      0.97      0.97       158
#           22       0.99      1.00      1.00       148
#           23       0.99      0.99      0.99       154
#           24       0.98      0.98      0.98       168
#           25       0.98      0.99      0.99       132
#
#     accuracy                           0.98      4000
#    macro avg       0.98      0.98      0.98      4000
# weighted avg       0.98      0.98      0.98      4000

# %% [markdown]
# # Confusion Matrix

# %%
cm = confusion_matrix(y_true, y_pred_classes)

plt.figure(figsize=(12,10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
